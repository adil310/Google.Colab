# %% [markdown]
# # 1.**Open Google Colab: Go to https://colab.research.google.com/ and create a new notebook or open an existing one.**
# # 2:Mount Google Drive: Run the following code snippet in a code cell:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **1.Import Pandas: Start by importing the Pandas library. This allows you to work with data in tabular form, including reading from and writing to CSV files.**
#
# **2: Create Data: Create a DataFrame with the data you want to write to the CSV file. You can create a DataFrame manually or by importing data from other sources.**
#
# **3:Write to CSV: Use the to_csv() method of the DataFrame to write the data to a CSV file. Specify the file path where you want to save the CSV file.**

# %%
import pandas as pd

# %%
path = ('/content/drive/MyDrive/housing.csv')
df = pd.read_csv(path)
df.head(150)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 145  2.37934   0.0  19.58     0  0.871  6.130  100.0  1.4191    5  403.0
# 146  2.15505   0.0  19.58     0  0.871  5.628  100.0  1.5166    5  403.0
# 147  2.36862   0.0  19.58     0  0.871  4.926   95.7  1.4608    5  403.0
# 148  2.33099   0.0  19.58     0  0.871  5.186   93.8  1.5296    5  403.0
# 149  2.73397   0.0  19.58     0  0.871  5.597   94.9  1.5257    5  403.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...
